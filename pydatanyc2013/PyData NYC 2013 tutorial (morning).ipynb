# %% [markdown]
# # How to count the rat complaints in New York with Python
#
# Follow along by downloading this presentation and running the code yourself:
#
# * This notebook: [http://bit.ly/data-fun](http://bit.ly/data-fun)
# * The data: [http://bit.ly/311-data-zip](http://bit.ly/311-data-zip). Originally from NYC Open Data
# * You can chat here: [https://etherpad.mozilla.org/pydata-workshop-morning](https://etherpad.mozilla.org/pydata-workshop-morning)
#
# Setup:
#
# * You can ask me any question, any time.
# * I'd rather cover *less* material and you have you understand more of it.
# * There will be exercises! Do them with a partner.

# %%
# ignore this!
# ignore me!
# This is just to make everything look prettier!
import pandas as pd
pd.set_option('display.mpl_style', 'default')
figsize(15, 6)
pd.set_option('display.line_width', 4000)
pd.set_option('display.max_columns', 100)

# %% [markdown]
# # Goal (Today): Learn how to find out
#
# ### 1. Which borough has the most rat complaints
# ### 2. Whether there are more noise complaints about houses of worship or helicopters
# ### 3. What people complain about on my street

# %% [markdown]
# # Step 1: Read our data from a file

# %%
# This reads the data from a file!
orig_data = pd.read_csv('./311-service-requests.csv', nrows=100000, parse_dates=['Created Date'])
orig_data['Street Name'].fillna("", inplace=True) # ignore this! This is replacing missing street names
# Look at the first 5 columns of the data
orig_data[:5]
# Out:
#    Unique Key        Created Date             Closed Date Agency                              Agency Name           Complaint Type                    Descriptor        Location Type Incident Zip  Incident Address      Street Name   Cross Street 1                    Cross Street 2 Intersection Street 1 Intersection Street 2 Address Type      City Landmark Facility Type    Status                Due Date Resolution Action Updated Date Community Board    Borough  X Coordinate (State Plane)  Y Coordinate (State Plane) Park Facility Name Park Borough  School Name School Number School Region  School Code School Phone Number School Address  School City School State   School Zip School Not Found  School or Citywide Complaint Vehicle Type Taxi Company Borough Taxi Pick Up Location Bridge Highway Name Bridge Highway Direction Road Ramp Bridge Highway Segment Garage Lot Name Ferry Direction Ferry Terminal Name   Latitude  Longitude                                  Location
# ...

# %%
plot(orig_data['Longitude'], orig_data['Latitude'], '.', color='purple')

# %% [markdown]
# #Exercise 0: Change the color of the plot above!

# %% [markdown]
# # Example 1: What do people complain about?

# %%
orig_data['Complaint Type']
# Out:
# 0      Noise - Street/Sidewalk
# 1              Illegal Parking
# 2           Noise - Commercial
# 3              Noise - Vehicle
# 4                       Rodent
# 5           Noise - Commercial
# 6             Blocked Driveway
# 7           Noise - Commercial
# 8           Noise - Commercial
# 9           Noise - Commercial
# 10    Noise - House of Worship
# 11          Noise - Commercial
# 12             Illegal Parking
# 13             Noise - Vehicle
# 14                      Rodent
# ...
# 99985                 Street Condition
# 99986                 Street Condition
# 99987                  Illegal Parking
# 99988                     Damaged Tree
# 99989                     Damaged Tree
# 99990                 Derelict Vehicle
# 99991           DOF Literature Request
# 99992           DOF Literature Request
# 99993    Root/Sewer/Sidewalk Condition
# 99994                            Sewer
# 99995         Benefit Card Replacement
# 99996          Overgrown Tree/Branches
# ...

# %%
orig_data['Complaint Type'].value_counts()
# Out:
# HEATING                     13983
# GENERAL CONSTRUCTION         6859
# Street Light Condition       6513
# DOF Literature Request       5107
# PLUMBING                     4884
# PAINT - PLASTER              4671
# Blocked Driveway             3992
# NONCONST                     3646
# Street Condition             3070
# Noise                        2942
# Traffic Signal Condition     2895
# Illegal Parking              2865
# Dirty Conditions             2364
# ELECTRIC                     2154
# Noise - Commercial           2120
# ...
# Window Guard                         2
# Legal Services Provider Complaint    2
# Public Assembly                      2
# Ferry Permit                         1
# Trans Fat                            1
# DFTA Literature Request              1
# Highway Sign - Damaged               1
# X-Ray Machine/Equipment              1
# DHS Income Savings Requirement       1
# Tunnel Condition                     1
# Snow                                 1
# ...

# %%
# Or we can make a graph!
orig_data['Complaint Type'].value_counts()[:20].plot(kind='bar')

# %% [markdown]
# # Exercise 1: Find out how many complaints there were in Manhattan
#
# (hint: look at the Borough column)

# %%
# your code here! (hint: look at the Borough column)

# %% [markdown]
# # Example 2: How many complaints are there in my zip code?

# %%
orig_data['Incident Zip'].value_counts()
# Out:
# 11226    1563
# 10467    1304
# 10458    1177
# 11233    1070
# 11207     993
# 11221     969
# 10468     964
# 10457     928
# 10032     917
# 11212     896
# 11225     880
# 10453     852
# 11208     851
# 11238     851
# 11203     841
# ...
# 11797.0       1
# 10162         1
# 02061         1
# 10048.0       1
# 92123.0       1
# 000000        1
# 11501.0       1
# 07020         1
# 11530.0       1
# 11563.0       1
# 61702         1
# 11580.0       1
# 77092-2016    1
# 11788.0       1
# 0.0           1
# Length: 433, dtype: int64

# %% [markdown]
# ## I can't see my zip code! We're going to have to do something else.

# %%
orig_data['Incident Zip'] == 11211
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# ...
# 99985    False
# 99986    False
# 99987    False
# 99988    False
# 99989    False
# 99990    False
# 99991    False
# 99992    False
# 99993    False
# 99994    False
# 99995    False
# 99996    False
# 99997    False
# 99998    False
# 99999    False
# Name: Incident Zip, Length: 100000, dtype: bool

# %%
just_my_zip = orig_data[orig_data['Incident Zip'] == 11211]

# %%
just_my_zip[:5]
# Out:
#        Unique Key        Created Date             Closed Date Agency                                        Agency Name     Complaint Type    Descriptor            Location Type Incident Zip    Incident Address     Street Name  Cross Street 1    Cross Street 2 Intersection Street 1 Intersection Street 2 Address Type      City Landmark Facility Type    Status                Due Date Resolution Action Updated Date Community Board   Borough  X Coordinate (State Plane)  Y Coordinate (State Plane) Park Facility Name Park Borough  School Name School Number School Region  School Code School Phone Number School Address  School City School State   School Zip School Not Found  School or Citywide Complaint Vehicle Type Taxi Company Borough Taxi Pick Up Location Bridge Highway Name Bridge Highway Direction Road Ramp                             Bridge Highway Segment Garage Lot Name Ferry Direction Ferry Terminal Name   Latitude  Longitude                                  Location
# ...

# %%
len(just_my_zip)
# Out:
# 126

# %% [markdown]
# ## So we have 126 complaints.

# %% [markdown]
# # Exercise 2: Find out how many complaints there are in your zip code!
#
# If that's too easy for you, try to find out if there are more complaints about rats or mice (check out the 'Complaint Type', and 'Descriptor' columns)

# %%
# your code here

# %% [markdown]
# # Example 3: Which borough complains the most about rats?

# %%
rodent_complaints = orig_data[orig_data['Complaint Type'] == 'Rodent']

# %%
rodent_complaints[:5]
# Out:
#      Unique Key        Created Date Closed Date Agency                              Agency Name Complaint Type                    Descriptor                  Location Type Incident Zip    Incident Address      Street Name  Cross Street 1                    Cross Street 2 Intersection Street 1 Intersection Street 2 Address Type      City Landmark Facility Type   Status                Due Date Resolution Action Updated Date Community Board    Borough  X Coordinate (State Plane)  Y Coordinate (State Plane) Park Facility Name Park Borough  School Name School Number School Region  School Code School Phone Number School Address  School City School State   School Zip School Not Found  School or Citywide Complaint Vehicle Type Taxi Company Borough Taxi Pick Up Location Bridge Highway Name Bridge Highway Direction Road Ramp Bridge Highway Segment Garage Lot Name Ferry Direction Ferry Terminal Name   Latitude  Longitude                                 Location
# ...

# %%
rodent_complaints['Borough']
# Out:
# 4      MANHATTAN
# 14      BROOKLYN
# 104    MANHATTAN
# 113     BROOKLYN
# 119     BROOKLYN
# 124     BROOKLYN
# 129     BROOKLYN
# 137        BRONX
# 209     BROOKLYN
# 255    MANHATTAN
# 279     BROOKLYN
# 316        BRONX
# 398    MANHATTAN
# 431        BRONX
# 448     BROOKLYN
# ...
# 98222       QUEENS
# 98245     BROOKLYN
# 98251     BROOKLYN
# 98279     BROOKLYN
# 98290        BRONX
# 98292        BRONX
# 98293        BRONX
# 98294        BRONX
# 98295    MANHATTAN
# 98298       QUEENS
# 98303     BROOKLYN
# 98329    MANHATTAN
# 98336        BRONX
# 98350     BROOKLYN
# 98351       QUEENS
# Name: Borough, Length: 1483, dtype: object

# %%
rodent_complaints['Borough'].value_counts()
# Out:
# BRONX            429
# BROOKLYN         424
# MANHATTAN        334
# QUEENS           215
# STATEN ISLAND     81
# dtype: int64

# %%
rodent_complaints['Borough'].value_counts().plot(kind='bar')

# %% [markdown]
# # Example 4: What kinds of noise complaints do people have?

# %%
orig_data['Complaint Type'].str.contains("Noise")
# Out:
# 0      True
# 1     False
# 2      True
# 3      True
# 4     False
# 5      True
# 6     False
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12    False
# 13     True
# 14    False
# ...
# 99985    False
# 99986    False
# 99987    False
# 99988    False
# 99989    False
# 99990    False
# 99991    False
# 99992    False
# 99993    False
# 99994    False
# 99995    False
# 99996    False
# 99997    False
# 99998    False
# 99999    False
# Name: Complaint Type, Length: 100000, dtype: bool

# %%
noise_complaints = orig_data[orig_data['Complaint Type'].str.contains("Noise")]

# %%
noise_complaints['Complaint Type'].value_counts()
# Out:
# Noise                       2942
# Noise - Commercial          2120
# Noise - Street/Sidewalk     1512
# Noise - Vehicle              619
# Noise - Park                 137
# Noise - Helicopter            96
# Noise - House of Worship      48
# Collection Truck Noise         7
# dtype: int64

# %% [markdown]
# # Example 4: What do people on my street complain about?

# %%
# Here's my street!
my_street = orig_data[orig_data['Street Name'].str.contains('SOUTH 4 STREET')]
my_street
# Out:
#        Unique Key        Created Date             Closed Date Agency                                        Agency Name                 Complaint Type                           Descriptor                  Location Type Incident Zip    Incident Address     Street Name   Cross Street 1   Cross Street 2 Intersection Street 1 Intersection Street 2 Address Type      City Landmark Facility Type    Status                Due Date Resolution Action Updated Date Community Board   Borough  X Coordinate (State Plane)  Y Coordinate (State Plane) Park Facility Name Park Borough  School Name School Number School Region  School Code School Phone Number School Address  School City School State   School Zip School Not Found  School or Citywide Complaint Vehicle Type Taxi Company Borough  Taxi Pick Up Location Bridge Highway Name Bridge Highway Direction Road Ramp Bridge Highway Segment Garage Lot Name Ferry Direction Ferry Terminal Name   Latitude  Longitude                                  Location
# ...

# %%
my_street['Complaint Type'].value_counts()
# Out:
# HEATING                          11
# PLUMBING                          4
# GENERAL CONSTRUCTION              4
# Sanitation Condition              3
# Dirty Conditions                  3
# Rodent                            3
# Graffiti                          2
# Street Condition                  2
# Taxi Complaint                    2
# Sidewalk Condition                1
# PAINT - PLASTER                   1
# General Construction/Plumbing     1
# Consumer Complaint                1
# Vending                           1
# dtype: int64

# %% [markdown]
# # Exercise 3: Find out what people complain about on your street

# %%
# You know the drill. If this is too easy, try to find how many streets there are with 'South' in them.
