# %%
import pandas as pd
pd.set_option('display.max_columns', 40)
pd.set_option('display.line_width', 400)

# %%
crashes = pd.read_csv('car_crashes_2007.csv')

# %%
crashes['Victim count'].sum()
# Out:
# 20888

# %%
crashes['Deaths'].sum()
# Out:
# 38

# %%
crashes[['Deaths', 'Serious Injuries', 'Injuries', 'Victim count']].sum()
# Out:
# Deaths                 38
# Serious Injuries      457
# Injuries            12213
# Victim count        20888
# dtype: int64

# %%
crashes['Intersection'].value_counts()
# Out:
# PIE IX / JEAN TALON                           23
# SHERBROOKE / LAPOINTE                         22
# DECARIE / PARE                                22
# 25 / TUNNEL LOUIS H LAFONTAINE                20
# LANGELIER / METROPOLITAN                      19
# HENRI BOURASSA / TUNNEL LOUIS H LAFONTAINE    16
# DE LORIMIER / ONTARIO                         16
# DECARIE / JEAN TALON                          16
# E / 15                                        15
# S / SHERBROOKE                                15
# N / JEAN TALON                                14
# HENRI BOURASSA / BERRI                        13
# O / ST CHARLES                                13
# SHERBROOKE / TRICENTENAIRE                    13
# D'IBERVILLE / ST JOSEPH                       12
# ...
# NOTRE-DAME DE GRACE / OLD ORCHARD    1
# O / STE ANNE                         1
# 2E AVE / JEAN TALON                  1
# HALPERN / HENRI BOURASSA             1
# RYAN / RENARD                        1
# ...

# %%
crashes[crashes['Intersection'] == 'PIE IX / JEAN TALON']
# Out:
#                                       Address   Latitude Cross Street  Street  Victim count  Injuries   Time  Serious Injuries                 Date  Latitude.1  Deaths         Intersection
# 4      PIE IX  & JEAN TALON, Montreal, Quebec -73.552521   JEAN TALON  PIE IX             2         2  20:40                 2  2007-01-01 00:00:00   45.554028       0  PIE IX / JEAN TALON
# 5      PIE IX  & JEAN TALON, Montreal, Quebec -73.552521   JEAN TALON  PIE IX             2         2  20:40                 2  2007-01-01 00:00:00   45.554028       0  PIE IX / JEAN TALON
# 6      PIE IX  & JEAN TALON, Montreal, Quebec -73.552521   JEAN TALON  PIE IX             3         2  20:40                 2  2007-01-01 00:00:00   45.554028       0  PIE IX / JEAN TALON
# 7      PIE IX  & JEAN TALON, Montreal, Quebec -73.552521   JEAN TALON  PIE IX             3         2  20:40                 2  2007-01-01 00:00:00   45.554028       0  PIE IX / JEAN TALON
# ...

# %%
crashes[:5]
# Out:
#                                           Address  Longitude   Cross Street      Street  Victim count  Injuries   Time  Serious Injuries                 Date   Latitude  Deaths
# 0             5610  ST JACQUES , Montreal, Quebec -73.606845         OXFORD  ST JACQUES             3         2   6:35                 0  2007-01-01 00:00:00  45.467678       0
# 1             5610  ST JACQUES , Montreal, Quebec -73.606845         OXFORD  ST JACQUES             3         2   6:35                 0  2007-01-01 00:00:00  45.467678       0
# 2   ST LAURENT  & RENE LEVESQUE, Montreal, Quebec -73.682930  RENE LEVESQUE  ST LAURENT             3         2   7:23                 0  2007-01-01 00:00:00  45.506962       0
# 3   ST LAURENT  & RENE LEVESQUE, Montreal, Quebec -73.682930  RENE LEVESQUE  ST LAURENT             3         2   7:23                 0  2007-01-01 00:00:00  45.506962       0
# ...
